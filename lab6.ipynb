# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
import statistics

# %%
data_inside = pd.read_csv('data.csv')
data_outside_raw= pd.read_csv('outside_data.csv')
temp_outside_true=data_outside_raw['Time']>(118+1677280327)
data_outside = data_outside_raw[temp_outside_true]

# %%
t_inside= data_inside['Temperature']
t_outside= data_outside['Temperature']

# %%
#step 3 plotting histograms
#df=pd.DataFrame(data_inside(temperature))
plt.hist(t_inside, bins=5, label='inside temperature', color='red',alpha=0.5)
plt.hist(t_outside, bins=10, label='outside',color='blue',alpha=0.5)
plt.title('Comparing temperature (Celsius) sensors at Etcheverry')
plt.legend(loc='upper right')
plt.show()

inside_m_t = statistics.mean(t_inside)
print("Mean of inside temperature:", inside_m_t)
inside_s_t = np.std(t_inside)
print("STD of inside temperature:", inside_s_t)

print("")

outside_m_t = statistics.mean(t_outside)
print("Mean of outside temperature:", outside_m_t)
outside_s_t = np.std(t_outside)
print("STD of outside temperature:", outside_s_t)
# Out:
# Mean of inside temperature: 22.333224206349207
# STD of inside temperature: 0.1296217716176203
#
# Mean of outside temperature: 19.86347826760913
# STD of outside temperature: 0.7347137460310075

# %%
#gas
g_inside= data_inside['Gas']
g_outside= data_outside['Gas']
plt.hist(g_inside, bins=10, label='inside', color='red',alpha=0.5)
plt.hist(g_outside, bins=10, label='outside',color='blue',alpha=0.5)
plt.title('Gas readings')
plt.legend(loc='upper right')
plt.show()

inside_m_g = statistics.mean(g_inside)
print("Mean of inside gas:", inside_m_g)
inside_s_g = np.std(g_inside)
print("STD of inside gas:", inside_s_g)

print("")

outside_m_g = statistics.mean(g_outside)
print("Mean of outside gas:", outside_m_g)
outside_s_g = np.std(g_outside)
print("STD of outside gas:", outside_s_g)
# Out:
# Mean of inside gas: 121525.95238095238
# STD of inside gas: 46156.24998605833
#
# Mean of outside gas: 239071.0158730159
# STD of outside gas: 18339.20479940041

# %%
#Humidity
h_inside= data_inside['Humidity']
h_outside= data_outside['Humidity']
plt.hist(h_inside, bins=10, label='inside ', color='red',alpha=0.5)
plt.hist(h_outside, bins=10, label='outside',color='blue',alpha=0.5)
plt.title('Humidity readings')
plt.legend(loc='upper right')
plt.show()

inside_m_h = statistics.mean(h_inside)
print("Mean of inside Humidity:", inside_m_h)
inside_s_h = np.std(h_inside)
print("STD of inside Humidity:", inside_s_h)

print("")

outside_m_h = statistics.mean(h_outside)
print("Mean of outside Humidity:", outside_m_h)
outside_s_h = np.std(h_outside)
print("STD of outside Humidity:", outside_s_h)
# Out:
# Mean of inside Humidity: 29.955395086355736
# STD of inside Humidity: 0.7600224326986457
#
# Mean of outside Humidity: 29.833591057237165
# STD of outside Humidity: 0.5121451054557706

# %%
#Pressure
p_inside= data_inside['Pressure']
p_outside= data_outside['Pressure']
plt.hist(p_inside, bins=10, label='inside ', color='red',alpha=0.5)
plt.hist(p_outside, bins=15, label='outside',color='blue',alpha=0.5)
plt.title('Pressure readings')
plt.legend(loc='upper right')
plt.show()

inside_m_p = statistics.mean(p_inside)
print("Mean of inside pressure:", inside_m_p)
inside_s_p = np.std(a_inside)
print("STD of inside pressure:", inside_s_p)

print("")

outside_m_p = statistics.mean(p_outside)
print("Mean of outside pressure:", outside_m_p)
outside_s_p = np.std(p_outside)
print("STD of outside pressure:", outside_s_p)
# Out:
# Mean of inside pressure: 996.8574064646226
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/j5/z_mk8z9j4cx062kn_5txnvlc0000gn/T/ipykernel_28949/303935717.py in <module>
#      10 inside_m_p = statistics.mean(p_inside)
#      11 print("Mean of inside pressure:", inside_m_p)
# ---> 12 inside_s_p = np.std(a_inside)
#      13 print("STD of inside pressure:", inside_s_p)
#      14
#
# NameError: name 'a_inside' is not defined

# %%
#Altitude
a_inside= data_inside['Altitude']
a_outside= data_outside['Altitude']
plt.hist(a_inside, bins=5, label='inside ', color='red',alpha=0.5)
plt.hist(a_outside, bins=10, label='outside',color='blue',alpha=0.5)
plt.title('Altitude readings')
plt.legend(loc='upper right')
plt.show()

inside_m = statistics.mean(a_inside)
print("Mean of inside altitude:", inside_m)
inside_s = np.std(a_inside)
print("STD of inside altitude:", inside_s)

print("")

outside_m = statistics.mean(a_outside)
print("Mean of outside altitude:", outside_m)
outside_s = np.std(a_outside)
print("STD of outside altitude:", outside_s)

# %%
#5
data_inside_2= pd.read_csv('inside_2.csv')
data_outside_raw_2= pd.read_csv('outside_2.csv')
data_outside_2=data_outside_raw_2[100:351]

display(data_outside_2)

# %%
#temperature
t_inside= data_inside['Temperature']
t_outside= data_outside['Temperature']
t_inside_2= data_inside_2['Temp']
t_outside_2= data_outside_2['Temp']

plt.hist(t_inside, bins=5, label='our inside dataset', color='red',alpha=0.5)
plt.hist(t_outside, bins=10, label='our outside dataset',color='blue',alpha=0.5)
plt.hist(t_inside_2, bins=20, label='their inside dataset', color='orange',alpha=0.5)
plt.hist(t_outside_2, bins=20, label='their outside dataset',color='green',alpha=0.5)
plt.title('Comparing temperature (Celsius) sensors at Etcheverry')
plt.legend(loc='upper right')
plt.show()

inside_m_t = statistics.mean(t_inside)
print("Mean of OUR inside temperature:", inside_m_t)
inside_s_t = np.std(t_inside)
print("STD of OUR inside temperature:", inside_s_t)

print("")

outside_m_t = statistics.mean(t_outside)
print("Mean of OUR outside temperature:", outside_m_t)
outside_s_t = np.std(t_outside)
print("STD of OUR outside temperature:", outside_s_t)
print("")
inside_m_t_2 = statistics.mean(t_inside_2)
print("Mean of THEIR inside temperature:", inside_m_t_2)
inside_s_t_2 = np.std(t_inside_2)
print("STD of THEIR inside temperature:", inside_s_t_2)

print("")

outside_m_t_2 = statistics.mean(t_outside_2)
print("Mean of THEIR outside temperature:", outside_m_t_2)
outside_s_t_2 = np.std(t_outside_2)
print("STD of THEIR outside temperature:", outside_s_t_2)

# %%
#temperature
g_inside= data_inside['Gas']
g_outside= data_outside['Gas']

g_inside_2= data_inside_2['Gas']
g_outside_2= data_outside_2['Gas']

plt.hist(g_inside, bins=10, label='OUR inside dataset', color='red',alpha=0.5)
plt.hist(g_outside, bins=10, label='OUR outside dataset',color='blue',alpha=0.5)
plt.hist(g_inside_2, bins=5, label='their inside dataset', color='orange',alpha=0.5)
plt.hist(g_outside_2, bins=5, label='their outside dataset',color='green',alpha=0.5)
plt.title('Gas readings')
plt.legend(loc='upper right')
plt.show()

inside_m_g = statistics.mean(g_inside)
print("Mean of inside gas:", inside_m_g)
inside_s_g = np.std(g_inside)
print("STD of inside gas:", inside_s_g)

print("")

outside_m_g = statistics.mean(g_outside)
print("Mean of outside gas:", outside_m_g)
outside_s_g = np.std(g_outside)
print("STD of outside gas:", outside_s_g)

print("")
inside_m_g_2 = statistics.mean(g_inside_2)
print("Mean of THEIR inside gas:", inside_m_g_2)
inside_s_g_2 = np.std(g_inside_2)
print("STD of THEIR inside gas:", inside_s_g_2)

print("")

outside_m_g_2 = statistics.mean(g_outside_2)
print("Mean of THEIR outside gas:", outside_m_g_2)
outside_s_g_2 = np.std(g_outside_2)
print("STD of THEIR outside gas:", outside_s_g_2)

# %%
#Humidity
h_inside= data_inside['Humidity']
h_outside= data_outside['Humidity']

h_inside_2= data_inside_2['Relative Humidity']
h_outside_2= data_outside_2['Relative Humidity']

plt.hist(h_inside, bins=10, label='our inside dataset', color='red',alpha=0.5)
plt.hist(h_outside, bins=10, label='our outside dataset',color='blue',alpha=0.5)
plt.hist(h_inside_2, bins=5, label='their inside dataset', color='orange',alpha=0.5)
plt.hist(h_outside_2, bins=10, label='their outside dataset',color='green',alpha=0.5)
plt.title('Humidity readings')
plt.legend(loc='upper right')
plt.show()

inside_m_h = statistics.mean(h_inside)
print("Mean of inside Humidity:", inside_m_h)
inside_s_h = np.std(h_inside)
print("STD of inside Humidity:", inside_s_h)

print("")

outside_m_h = statistics.mean(h_outside)
print("Mean of outside Humidity:", outside_m_h)
outside_s_h = np.std(h_outside)
print("STD of outside Humidity:", outside_s_h)

print("")
inside_m_h_2 = statistics.mean(h_inside_2)
print("Mean of THEIR inside Humidity:", inside_m_h_2)
inside_s_h_2 = np.std(h_inside_2)
print("STD of THEIR inside Humidity:", inside_s_h_2)

print("")

outside_m_h_2 = statistics.mean(h_outside_2)
print("Mean of THEIR outside Humidity:", outside_m_h_2)
outside_s_h_2 = np.std(h_outside_2)
print("STD of THEIR outside Humidity:", outside_s_h_2)

# %%
#Pressure
p_inside= data_inside['Pressure']
p_outside= data_outside['Pressure']

p_inside_2= data_inside_2['Pressure']
p_outside_2= data_outside_2['Pressure']


plt.hist(p_inside, bins=10, label='our inside dataset', color='red',alpha=0.5)
plt.hist(p_outside, bins=15, label='our outside dataset',color='blue',alpha=0.5)
plt.hist(p_inside_2, bins=5, label='their inside dataset', color='orange',alpha=0.5)
plt.hist(p_outside_2, bins=10, label='their outside dataset',color='green',alpha=0.5)
plt.title('Pressure readings')
plt.legend(loc='upper right')
plt.show()

inside_m_p = statistics.mean(p_inside)
print("Mean of inside pressure:", inside_m_p)
inside_s_p = np.std(a_inside)
print("STD of inside pressure:", inside_s_p)

print("")

outside_m_p = statistics.mean(p_outside)
print("Mean of outside pressure:", outside_m_p)
outside_s_p = np.std(p_outside)
print("STD of outside pressure:", outside_s_p)

print("")
inside_m_p_2 = statistics.mean(p_inside_2)
print("Mean of THEIR inside pressure:", inside_m_p_2)
inside_s_p_2 = np.std(p_inside_2)
print("STD of THEIR inside pressure:", inside_s_p_2)

print("")

outside_m_p_2 = statistics.mean(p_outside_2)
print("Mean of THEIR outside pressure:", outside_m_p_2)
outside_s_p_2 = np.std(p_outside_2)
print("STD of THEIR outside pressure:", outside_s_p_2)

# %%
#Altitude
a_inside= data_inside['Altitude']
a_outside= data_outside['Altitude']

a_inside_2= data_inside_2['Altitude']
a_outside_2= data_outside_2['Altitude']


plt.hist(a_inside, bins=5, label='our inside dataset', color='red',alpha=0.5)
plt.hist(a_outside, bins=15, label='our outside dataset',color='blue',alpha=0.5)
plt.hist(a_inside_2, bins=5, label='their inside dataset', color='orange',alpha=0.5)
plt.hist(a_outside_2, bins=10, label='their outside dataset',color='green',alpha=0.5)
plt.title('Altitude readings')
plt.legend(loc='upper right')
plt.show()

inside_m = statistics.mean(a_inside)
print("Mean of inside altitude:", inside_m)
inside_s = np.std(a_inside)
print("STD of inside altitude:", inside_s)

print("")

outside_m = statistics.mean(a_outside)
print("Mean of outside altitude:", outside_m)
outside_s = np.std(a_outside)
print("STD of outside altitude:", outside_s)

print("")
inside_m_a_2 = statistics.mean(a_inside_2)
print("Mean of THEIR inside altitude:", inside_m_a_2)
inside_s_a_2 = np.std(a_inside_2)
print("STD of THEIR inside altitude:", inside_s_a_2)

print("")

outside_m_a_2 = statistics.mean(a_outside_2)
print("Mean of THEIR outside altitude:", outside_m_a_2)
outside_s_a_2 = np.std(a_outside_2)
print("STD of THEIR outside altitude:", outside_s_a_2)

# %% [markdown]
# ## The data differs a bit for the temperature there was a vast change between the data sets, this could be due to the sensor loosing some of its sensitivty. Perhaps ours has been used more overtime. However, other readings of the data is very similar only small variations
